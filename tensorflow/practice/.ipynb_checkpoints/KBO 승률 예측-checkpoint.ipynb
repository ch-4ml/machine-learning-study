# %% [markdown]
# # KBO 승률 예측
#
# <b>각 시즌의 팀 별 성적(Stat)이 좋으면 승률이 좋다</b>는 가설을 세우고 이를 증명하기 위한 프로젝트 시작
#
# 성적과 승률의 상관관계를 검증
#
# 어떤 의미를 갖는가? 현재까지의 성적을 가지고 승률, 순위 예측에 활용할 수 있다.

# %% [markdown]
# ---

# %% [markdown]
# ## 필요한 라이브러리 가져오기

# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

mpl.rc('font', family='NanumGothic')  # matplotlib에서 한글 폰트로 NanumGothic을 사용
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 학습에 사용할 데이터

# %% [markdown]
# KBO 리그의 세이버메트릭스를 전문적으로 다루는 야구 통계 사이트인 Statiz와 KBO 기록실에서 크롤링하여 합친 데이터
#
# 데이터 설명에 추가 필요

# %% [markdown]
# ### 데이터 가져오기

# %%
data = pd.read_csv('./KBO_1982_2020_Team_Stats_Rank_EN.csv')
data.head()
# Out:
#    No Name  Year  G_B    PA    AB  R_B  H_B  2B_B  3B_B  ...   ERA+   FIP+  \
# 0   1  MBC  1982  952  3061  2686  419  757   124    12  ...  113.0  112.6
# 1   2   삼성  1982  887  3043  2647  429  705   126    18  ...  147.1  113.2
# 2   3   OB  1982  930  3098  2745  399  778   137    23  ...  121.6  108.3
# 3   4   해태  1982  873  2990  2665  374  696   110    14  ...  101.7  102.8
# 4   5   롯데  1982  863  3062  2628  353  674   112     8  ...  100.6  105.7
#
#    WAR_P  WPA_P  Rank   G  W_T  L_T  D      P
# 0  16.09    NaN     3  80   46   34  0  0.575
# 1  21.11    NaN     2  80   54   26  0  0.675
# 2  18.28    NaN     1  80   56   24  0  0.700
# 3  11.88    NaN     4  80   38   42  0  0.475
# 4  13.66    NaN     5  80   31   49  0  0.388
#
# [5 rows x 65 columns]

# %%
data['P'].describe()
# Out:
# count    299.000000
# mean       0.503321
# std        0.086801
# min        0.188000
# 25%        0.448000
# 50%        0.508000
# 75%        0.563000
# max        0.706000
# Name: P, dtype: float64

# %%
print(data.shape)
# Out:
# (299, 65)

# %% [markdown]
# ### 승률 데이터의 분포

# %%
data['P'].hist(bins=100)

# %%
data.boxplot(column=['P'])

# %% [markdown]
# Outliers가 3개 표시되는데, 데이터를 살펴봤을 때 승률(P)이 차례로 <b>0.188, 0.25, 0.265</b> 인 데이터였다.
#
# 이 데이터들은 학습 시 포함, 제외 두 가지 경우를 모두 수행할 것이다.

# %% [markdown]
# ### NaN, 빈 셀 처리

# %% [markdown]
# 데이터 특성 상 빈 값을 0으로 채우는 것이 학습 결과에 가장 적은 영향을 미칠 것으로 판단했기 때문에 빈 셀은 0으로 처리한다.

# %%
data = data.fillna(0)
data.head()
# Out:
#    No Name  Year  G_B    PA    AB  R_B  H_B  2B_B  3B_B  ...   ERA+   FIP+  \
# 0   1  MBC  1982  952  3061  2686  419  757   124    12  ...  113.0  112.6
# 1   2   삼성  1982  887  3043  2647  429  705   126    18  ...  147.1  113.2
# 2   3   OB  1982  930  3098  2745  399  778   137    23  ...  121.6  108.3
# 3   4   해태  1982  873  2990  2665  374  696   110    14  ...  101.7  102.8
# 4   5   롯데  1982  863  3062  2628  353  674   112     8  ...  100.6  105.7
#
#    WAR_P  WPA_P  Rank   G  W_T  L_T  D      P
# 0  16.09    0.0     3  80   46   34  0  0.575
# 1  21.11    0.0     2  80   54   26  0  0.675
# 2  18.28    0.0     1  80   56   24  0  0.700
# 3  11.88    0.0     4  80   38   42  0  0.475
# 4  13.66    0.0     5  80   31   49  0  0.388
#
# [5 rows x 65 columns]

# %%
data.to_csv('ttt.csv', encoding='cp949', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## 회귀 분석

# %% [markdown]
# 먼저 기계학습을 통해 회귀 분석을 진행한다.
#
# 야구 데이터의 특성 상 다중공선성이 높게 나타나기 때문에 전처리 과정에서 VIF 계수를 측정해 학습에 사용할 변수를 걸러내고
#
# 그럼에도 특성들이 상관관계가 있다면, 규제가 있는 모델을 이용해서 학습한다.

# %% [markdown]
# ### Feature, Label 분리

# %%
X = data[data.columns.difference(['No', 'Name', 'P'])]
y = data['P']

# %% [markdown]
# ### Feature의 상관관계 분석

# %%
import seaborn as sns

# 특성 간의 상관계수 행렬을 계산합니다.
corr = data[data.columns].corr(method='pearson')

# corr 행렬 히트맵을 시각화합니다.
plt.rc('font', family='NanumGothic')
plt.figure(figsize=(40, 40))

sns.set(font_scale=1.2)
hm = sns.heatmap(corr.values,
            cbar=True,
            annot=True, 
            square=True,
            fmt='.2f',
            annot_kws={'size': 12},
            yticklabels=X.columns,
            xticklabels=X.columns)

plt.tight_layout()
plt.show()

# %% [markdown]
# Feature 수가 많아 숫자가 정확히 보이지는 않지만, 색깔 만으로도 높은 상관관계를 가진 Feature가 많다는 사실을 확인할 수 있다.

# %% [markdown]
# ### 다중공선성 확인

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# 생략 row수 제한 해제
pd.set_option('display.max_rows', 62)

# 각 특성의 VIF 계수 출력
vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['features'] = X.columns
vif.round(1)
# Out:
#     VIF Factor features
# 0         31.5     2B_P
# 1         14.8     3B_P
# 2      20303.2       AB
# 3       7282.5      AVG
# 4        587.3     BB_B
# 5       3218.7     BB_P
# 6          4.6       BK
# 7         22.3       CG
# 8         42.1       CS
# 9      15027.9       ER
# 10     12327.8      ERA
# 11      3204.7     ERA+
# 12      5248.6      FIP
# 13      5990.9     FIP+
# 14       112.5      GDP
# 15     36446.7       GS
# 16       570.5      G_B
# 17       333.9      G_P
# 18        40.5    HBP_B
# 19        38.7    HBP_P
# 20        20.0  HLD(HD)
# 21       192.8     HR_P
# 22     19678.8      H_P
# 23        13.8    IBB_B
# 24         6.8    IBB_P
# 25      1763.1      L_P
# 26      6515.7      RBI
# 27      7009.7      R_B
# 28      4958.4      R_P
# 29        31.9     Rank
# 30        35.2      SAC
# 31        32.1       SB
# 32        43.4       SF
# 33      4935.0      SLG
# 34       204.2     SO_B
# 35       320.7     SO_P
# 36        57.0       SV
# 37         7.6      ShO
# 38     38061.2      TBF
# 39       334.0    WAR_B
# 40       246.2    WAR_P
# 41     27282.8     WHIP
# 42        34.2       WP
# 43         4.6    WPA_B
# 44         4.2    WPA_P
# 45      1723.8      W_P
# 46     21914.9     Year
# 47     26819.4     wOBA
# 48      4177.5     wRC+

# %% [markdown]
# ### 다중공선성이 높은 Feature를 제거
#
# 여러 차례 다중공선성 검사를 반복하고, 높은 Feature를 제거합니다.
#
# 각 차례를 모두 기록합니다.

# %% [markdown]
# <b>1. VIF 계수가 발산하는 Feature 제거: '2B_B', '3B_B', 'D', 'G', 'HR_B', 'H_B', 'L_T', 'TB', 'W_T'</b>

# %%
X = X.drop(['2B_B', '3B_B', 'D', 'G', 'HR_B', 'H_B', 'L_T', 'TB', 'W_T'], axis=1)
# Out:
# Index(['2B_P', '3B_P', 'AB', 'AVG', 'BB_B', 'BB_P', 'BK', 'CG', 'CS', 'ER',
#        'ERA', 'ERA+', 'FIP', 'FIP+', 'GDP', 'GS', 'G_B', 'G_P', 'HBP_B',
#        'HBP_P', 'HLD(HD)', 'HR_P', 'H_P', 'IBB_B', 'IBB_P', 'IP', 'L_P', 'OBP',
#        'OPS', 'PA', 'RBI', 'R_B', 'R_P', 'Rank', 'SAC', 'SB', 'SF', 'SLG',
#        'SO_B', 'SO_P', 'SV', 'ShO', 'TBF', 'WAR_B', 'WAR_P', 'WHIP', 'WP',
#        'WPA_B', 'WPA_P', 'W_P', 'Year', 'wOBA', 'wRC+'],
#       dtype='object')

# %% [markdown]
# <b> 2. VIF 계수가 가장 높은 Feature 제거: 'PA'</b>

# %%
X = X.drop(['PA'], axis=1)
# Out:
# Index(['2B_P', '3B_P', 'AB', 'AVG', 'BB_B', 'BB_P', 'BK', 'CG', 'CS', 'ER',
#        'ERA', 'ERA+', 'FIP', 'FIP+', 'GDP', 'GS', 'G_B', 'G_P', 'HBP_B',
#        'HBP_P', 'HLD(HD)', 'HR_P', 'H_P', 'IBB_B', 'IBB_P', 'IP', 'L_P', 'OBP',
#        'OPS', 'RBI', 'R_B', 'R_P', 'Rank', 'SAC', 'SB', 'SF', 'SLG', 'SO_B',
#        'SO_P', 'SV', 'ShO', 'TBF', 'WAR_B', 'WAR_P', 'WHIP', 'WP', 'WPA_B',
#        'WPA_P', 'W_P', 'Year', 'wOBA', 'wRC+'],
#       dtype='object')

# %% [markdown]
# <b>3. VIF 계수가 가장 높은 Feature 제거: 'OPS'</b>

# %%
X = X.drop(['OPS'], axis=1)
# Out:
# Index(['2B_P', '3B_P', 'AB', 'AVG', 'BB_B', 'BB_P', 'BK', 'CG', 'CS', 'ER',
#        'ERA', 'ERA+', 'FIP', 'FIP+', 'GDP', 'GS', 'G_B', 'G_P', 'HBP_B',
#        'HBP_P', 'HLD(HD)', 'HR_P', 'H_P', 'IBB_B', 'IBB_P', 'IP', 'L_P', 'OBP',
#        'RBI', 'R_B', 'R_P', 'Rank', 'SAC', 'SB', 'SF', 'SLG', 'SO_B', 'SO_P',
#        'SV', 'ShO', 'TBF', 'WAR_B', 'WAR_P', 'WHIP', 'WP', 'WPA_B', 'WPA_P',
#        'W_P', 'Year', 'wOBA', 'wRC+'],
#       dtype='object')

# %% [markdown]
# <b>4. VIF 계수가 가장 높은 Feature 제거: 'OBP'</b>

# %%
X = X.drop(['OBP'], axis=1)
# Out:
# Index(['2B_P', '3B_P', 'AB', 'AVG', 'BB_B', 'BB_P', 'BK', 'CG', 'CS', 'ER',
#        'ERA', 'ERA+', 'FIP', 'FIP+', 'GDP', 'GS', 'G_B', 'G_P', 'HBP_B',
#        'HBP_P', 'HLD(HD)', 'HR_P', 'H_P', 'IBB_B', 'IBB_P', 'IP', 'L_P', 'RBI',
#        'R_B', 'R_P', 'Rank', 'SAC', 'SB', 'SF', 'SLG', 'SO_B', 'SO_P', 'SV',
#        'ShO', 'TBF', 'WAR_B', 'WAR_P', 'WHIP', 'WP', 'WPA_B', 'WPA_P', 'W_P',
#        'Year', 'wOBA', 'wRC+'],
#       dtype='object')

# %% [markdown]
# <b>5. VIF 계수가 가장 높은 Feature 제거: 'IP'</b>

# %%
X = X.drop(['IP'], axis=1)
# Out:
# Index(['2B_P', '3B_P', 'AB', 'AVG', 'BB_B', 'BB_P', 'BK', 'CG', 'CS', 'ER',
#        'ERA', 'ERA+', 'FIP', 'FIP+', 'GDP', 'GS', 'G_B', 'G_P', 'HBP_B',
#        'HBP_P', 'HLD(HD)', 'HR_P', 'H_P', 'IBB_B', 'IBB_P', 'L_P', 'RBI',
#        'R_B', 'R_P', 'Rank', 'SAC', 'SB', 'SF', 'SLG', 'SO_B', 'SO_P', 'SV',
#        'ShO', 'TBF', 'WAR_B', 'WAR_P', 'WHIP', 'WP', 'WPA_B', 'WPA_P', 'W_P',
#        'Year', 'wOBA', 'wRC+'],
#       dtype='object')

# %% [markdown]
# <b>6. VIF 계수가 가장 높은 Feature 제거: 'TBF'</b>

# %%
X = X.drop(['TBF'], axis=1)

# %%
X.columns

# %% [markdown]
# ### 다중공선성 확인 반복
# [<h3>최대 VIF 계수가 10이 넘지 않을 때 까지 반복해주세요. 클릭 시 위로 올라갑니다.</h3>](#다중공선성-확인)

# %% [markdown]
# ---

# %% [markdown]
# ## 딥러닝

# %% [markdown]
# 샘플 개수가 적을 수록 과대적합이 쉽게 일어나기 때문에 작은 모델을 사용하는 것이 과대적합을 피하는 방법이 될 수 있다.
#
# 본 프로젝트에서는 64개의 유닛을 가진 2개의 은닉 층으로 작은 네트워크를 구성해서 사용한다.

# %% [markdown]
# ---
